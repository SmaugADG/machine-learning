# %%
import pandas as pd
import numpy as np

# %%
# 文件读取
data = pd.read_csv("stock_day.csv")

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-13  21.40  21.90  21.48  21.31   30802.45          0.28      1.32
# 2018-02-12  20.70  21.40  21.19  20.63   32445.39          0.82      4.03
# 2018-02-09  21.20  21.46  20.36  20.19   54304.01         -1.50     -6.86
# 2018-02-08  21.79  22.09  21.88  21.75   27068.16          0.09      0.41
# 2018-02-07  22.69  23.11  21.80  21.29   53853.25         -0.50     -2.24
# 2018-02-06  22.80  23.55  22.29  22.20   55555.00         -0.97     -4.17
# 2018-02-05  22.45  23.39  23.27  22.25   52341.39          0.65      2.87
# ...

# %%
# 删除一些列，让数据简单显示
data = data.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"], axis=1)

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-13  21.40  21.90  21.48  21.31   30802.45          0.28      1.32
# 2018-02-12  20.70  21.40  21.19  20.63   32445.39          0.82      4.03
# 2018-02-09  21.20  21.46  20.36  20.19   54304.01         -1.50     -6.86
# 2018-02-08  21.79  22.09  21.88  21.75   27068.16          0.09      0.41
# 2018-02-07  22.69  23.11  21.80  21.29   53853.25         -0.50     -2.24
# 2018-02-06  22.80  23.55  22.29  22.20   55555.00         -0.97     -4.17
# 2018-02-05  22.45  23.39  23.27  22.25   52341.39          0.65      2.87
# ...

# %%
# 直接索引

stock_change=np.random.normal(0,1,(10,5))

# %%
stock_change[1,1]
# Out:
# 0.302572301405638

# %%
# data[1,0] # 不能直接进行索引

# %%
# 必须先列后行
data["open"]["2018-02-26"]
# Out:
# 22.8

# %%
# 要使用先行后列 需要使用data.loc
data.loc["2018-02-26"]["open"]
# Out:
# 22.8

# %%
# 按照数字索引
data.iloc[1,0]
# Out:
# 22.8

# %%
# ix组合索引
# 获取行第1天到第4天，['open', 'close', 'high', 'low']这个四个指标的结果
data.ix[:4,['open', 'close', 'high', 'low']]
# Out:
# /home/smaugadg/.virtualenvs/~AI-python3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
#              open  close   high    low
# 2018-02-27  23.53  24.16  25.88  23.53
# 2018-02-26  22.80  23.53  23.78  22.80
# 2018-02-23  22.88  22.82  23.37  22.71
# 2018-02-22  22.25  22.28  22.76  22.02

# %%
# 赋值操作

# %%
data.open=100
data.head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   100  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
# 排序

# %%
# 内容排序
# DataFromat

# %%
# ascending默认True,从小到大排序
data.sort_values(by=["high","p_change"],ascending=False).head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-06-10   100  36.35  33.85  32.23  269033.12          0.51      1.53
# 2015-06-12   100  35.98  35.21  34.01  159825.88          0.82      2.38
# 2017-10-31   100  35.22  34.44  32.20  361660.88          2.38      7.42
# 2015-06-15   100  34.99  31.69  31.69  199369.53         -3.52    -10.00
# 2015-06-11   100  34.98  34.39  32.51  173075.73          0.54      1.59
#
#             turnover
# 2015-06-10      9.21
# 2015-06-12      5.47
# 2017-10-31      9.05
# 2015-06-15      6.82
# 2015-06-11      5.92

# %%
# 索引排序
data.sort_index().head()
# Out:
#             open   high  close    low     volume  price_change  p_change  \
# 2015-03-02   100  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-03   100  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-04   100  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-05   100  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-06   100  14.48  14.28  13.13  179831.72          1.12      8.51
#
#             turnover
# 2015-03-02      3.30
# 2015-03-03      4.76
# 2015-03-04      2.30
# 2015-03-05      3.19
# 2015-03-06      6.16

# %%
# 使用序列
sr=data["price_change"]
sr.sort_index().head()
# Out:
# 2015-03-02    0.32
# 2015-03-03    0.18
# 2015-03-04    0.20
# 2015-03-05    0.26
# 2015-03-06    1.12
# Name: price_change, dtype: float64

# %%
sr.sort_values().head()
# Out:
# 2015-06-15   -3.52
# 2017-11-02   -3.38
# 2015-06-19   -3.12
# 2015-05-28   -2.80
# 2015-07-14   -2.73
# Name: price_change, dtype: float64

# %% [markdown]
# ### DataFrame运算

# %%
# 算术运算
# data["open"]+3
data["open"].add(3).head()
# Out:
# 2018-02-27    103
# 2018-02-26    103
# 2018-02-23    103
# 2018-02-22    103
# 2018-02-14    103
# Name: open, dtype: int64

# %%
# 逻辑运算

# %%
data[data["p_change"]>2].head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   100  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
data[(data["p_change"])>2&(data["low"]>15)].head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   100  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22   100  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-22      0.90
# 2018-02-14      0.58

# %%
data.query("p_change>2 & low>15").head()
# Out:
#             open   high  close    low    volume  price_change  p_change  \
# 2018-02-27   100  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26   100  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23   100  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-14   100  21.99  21.92  21.48  23331.04          0.44      2.05
# 2018-02-12   100  21.40  21.19  20.63  32445.39          0.82      4.03
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# 2018-02-23      1.32
# 2018-02-14      0.58
# 2018-02-12      0.81

# %%
# 统计运算

# %%
data.describe().head()
# Out:
#         open        high       close         low        volume  price_change  \
# count  643.0  643.000000  643.000000  643.000000    643.000000    643.000000
# mean   100.0   21.900513   21.336267   20.771835  99905.519114      0.018802
# std      0.0    4.077578    3.942806    3.791968  73879.119354      0.898476
# min    100.0   12.670000   12.360000   12.200000   1158.120000     -3.520000
# 25%    100.0   19.500000   19.045000   18.525000  48533.210000     -0.390000
#
#          p_change    turnover
# count  643.000000  643.000000
# mean     0.190280    2.936190
# std      4.079698    2.079375
# min    -10.030000    0.040000
# 25%     -1.850000    1.360000

# %%
# 统计函数
data["open"].max()
# Out:
# 100

# %%
data.idxmax()
# Out:
# open            2018-02-27
# high            2015-06-10
# close           2015-06-12
# low             2015-06-12
# volume          2017-10-26
# price_change    2015-06-09
# p_change        2015-08-28
# turnover        2017-10-26
# dtype: object

# %%
# 累计统计函数
# 需要查看 走势需要累计统计
data["p_change"].sort_index().cumsum().plot()

# %%
# 自定义 运算

# %%
# apply（func，axis=0）
# func:自定义函数
# axis=0:默认列，axis=1：为行

# %%
data.apply(lambda x: x.max()-x.min())
# Out:
# open                 0.00
# high                23.68
# close               22.85
# low                 21.81
# volume          500757.29
# price_change         6.55
# p_change            20.06
# turnover            12.52
# dtype: float64

# %% [markdown]
# ### Pandas画图

# %%
# DataFrame画图

# %%
data.plot(x="volume",y="turnover",kind="scatter")

# %% [markdown]
# ### 文件读取与存储

# %%
# 读取CSV
data2=pd.read_csv("stock_day.csv",usecols=["high","low","open","close"])
data2.head()
# Out:
#              open   high  close    low
# 2018-02-27  23.53  25.88  24.16  23.53
# 2018-02-26  22.80  23.78  23.53  22.80
# 2018-02-23  22.88  23.37  22.82  22.71
# 2018-02-22  22.25  22.76  22.28  22.02
# 2018-02-14  21.49  21.99  21.92  21.48

# %%
data3=pd.read_csv("stock_day2.csv",names=["open", "high", "close", "low", "volume", "price_change", "p_change", "ma5", "ma10", "ma20", "v_ma5", "v_ma10", "v_ma20", "turnover"])

# %%
data3.head()
# Out:
#              open   high  close    low    volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53  95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80  60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71  52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02  36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48  23331.04          0.44      2.05
#
#                ma5    ma10    ma20     v_ma5    v_ma10    v_ma20  turnover
# 2018-02-27  22.942  22.142  22.875  53782.64  46738.65  55576.11      2.39
# 2018-02-26  22.406  21.955  22.942  40827.52  42736.34  56007.50      1.53
# 2018-02-23  21.938  21.929  23.022  35119.58  41871.97  56372.85      1.32
# 2018-02-22  21.446  21.909  23.137  35397.58  39904.78  60149.60      0.90
# 2018-02-14  21.366  21.923  23.253  33590.21  42935.74  61716.11      0.58

# %%
# 保存open列
data[:10].to_csv("test.csv",columns=['open'],index=False,mode="a",header=False)

# %%
pd.read_csv("test.csv").head()
# Out:
#   open
# 0  100
# 1  100
# 2  100
# 3  100
# 4  100

# %%
# HDF5
day_close=pd.read_hdf("./stock_data/day/day_close.h5")

# %%
day_close.head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      16.30      17.71       4.58       2.88      14.60       2.62
# 1      17.02      19.20       4.65       3.02      15.97       2.65
# 2      17.02      17.28       4.56       3.06      14.37       2.63
# 3      16.18      16.97       4.49       2.95      13.10       2.73
# 4      16.95      17.19       4.55       2.99      13.18       2.77
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ    ...      001965.SZ  \
# 0       4.96       4.66       5.37       6.02    ...            NaN
# 1       4.95       4.70       5.37       6.27    ...            NaN
# 2       4.82       4.47       5.37       5.96    ...            NaN
# 3       4.89       4.33       5.37       5.77    ...            NaN
# 4       4.97       4.42       5.37       5.92    ...            NaN
#
#    603283.SH  002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
day_close.to_hdf("test.h5",key="close")

# %%
new_day_close=pd.read_hdf("test.h5")
new_day_close.head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      16.30      17.71       4.58       2.88      14.60       2.62
# 1      17.02      19.20       4.65       3.02      15.97       2.65
# 2      17.02      17.28       4.56       3.06      14.37       2.63
# 3      16.18      16.97       4.49       2.95      13.10       2.73
# 4      16.95      17.19       4.55       2.99      13.18       2.77
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ    ...      001965.SZ  \
# 0       4.96       4.66       5.37       6.02    ...            NaN
# 1       4.95       4.70       5.37       6.27    ...            NaN
# 2       4.82       4.47       5.37       5.96    ...            NaN
# 3       4.89       4.33       5.37       5.77    ...            NaN
# 4       4.97       4.42       5.37       5.92    ...            NaN
#
#    603283.SH  002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
day_open=pd.read_hdf("./stock_data/day/day_open.h5")
day_open.head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      15.50      16.15       4.26       2.73      13.99       2.52
# 1      16.50      17.94       4.53       2.91      14.78       2.61
# 2      17.00      18.80       4.63       3.04      16.08       2.65
# 3      16.95      16.59       4.52       3.02      13.20       2.63
# 4      16.20      16.96       4.50       2.95      13.17       2.80
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ    ...      001965.SZ  \
# 0       4.76       4.45       5.37       5.79    ...            NaN
# 1       4.99       4.69       5.37       6.03    ...            NaN
# 2       4.96       4.73       5.37       6.26    ...            NaN
# 3       4.81       4.35       5.37       5.74    ...            NaN
# 4       4.88       4.34       5.37       5.80    ...            NaN
#
#    603283.SH  002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
day_open.to_hdf("test.h5",key="open")

# %%
pd.read_hdf("test.h5",key="open").head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      15.50      16.15       4.26       2.73      13.99       2.52
# 1      16.50      17.94       4.53       2.91      14.78       2.61
# 2      17.00      18.80       4.63       3.04      16.08       2.65
# 3      16.95      16.59       4.52       3.02      13.20       2.63
# 4      16.20      16.96       4.50       2.95      13.17       2.80
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ    ...      001965.SZ  \
# 0       4.76       4.45       5.37       5.79    ...            NaN
# 1       4.99       4.69       5.37       6.03    ...            NaN
# 2       4.96       4.73       5.37       6.26    ...            NaN
# 3       4.81       4.35       5.37       5.74    ...            NaN
# 4       4.88       4.34       5.37       5.80    ...            NaN
#
#    603283.SH  002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
# JSON

# %%
sa=pd.read_json("Sarcasm_Headlines_Dataset.json",orient="records",lines=True)

# %%
sa.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %%
sa.to_json("test.json",orient="records",lines=True)
