# %%
import numpy as np
# 创建一个符合正泰分布的10 个股票的5天的涨跌幅
stock_change=np.random.normal(0,1,(10,5))

# %%
stock_change
# Out:
# array([[ 0.60285313, -1.31514826, -0.09034986, -1.56760496, -0.57970034],
#        [ 0.76955317,  0.51048755,  1.86244757, -0.05245673, -0.15793113],
#        [ 2.13084099,  0.24159464, -0.72320166, -0.34197566, -0.30331801],
#        [-1.55473866,  0.04423487,  0.181659  ,  2.01298332,  1.66929339],
#        [ 0.14632285, -1.33484076, -0.82137247, -0.30413048,  2.19656638],
#        [-0.56297611,  1.56339101, -0.32158122, -1.64871465,  0.19868331],
#        [-0.06827659,  0.53106893, -1.77830019,  1.11206786, -0.31957809],
#        [-0.55313933, -0.3076756 , -1.97747908, -0.40418892, -0.14943198],
#        [-0.45256832,  1.67894313,  1.42611712,  1.65767857,  0.01101082],
#        [ 0.71875098, -0.45579611,  1.1091478 ,  0.53727524, -0.52999865]])

# %%
import pandas as pd
pd.DataFrame(stock_change)
# Out:
#           0         1         2         3         4
# 0  0.602853 -1.315148 -0.090350 -1.567605 -0.579700
# 1  0.769553  0.510488  1.862448 -0.052457 -0.157931
# 2  2.130841  0.241595 -0.723202 -0.341976 -0.303318
# 3 -1.554739  0.044235  0.181659  2.012983  1.669293
# 4  0.146323 -1.334841 -0.821372 -0.304130  2.196566
# 5 -0.562976  1.563391 -0.321581 -1.648715  0.198683
# 6 -0.068277  0.531069 -1.778300  1.112068 -0.319578
# 7 -0.553139 -0.307676 -1.977479 -0.404189 -0.149432
# 8 -0.452568  1.678943  1.426117  1.657679  0.011011
# 9  0.718751 -0.455796  1.109148  0.537275 -0.529999

# %%
# 添加行索引
stock=["股票{}".format(i) for i in range(10)]

# %%
pd.DataFrame(stock_change,index=stock)
# Out:
#             0         1         2         3         4
# 股票0  0.602853 -1.315148 -0.090350 -1.567605 -0.579700
# 股票1  0.769553  0.510488  1.862448 -0.052457 -0.157931
# 股票2  2.130841  0.241595 -0.723202 -0.341976 -0.303318
# 股票3 -1.554739  0.044235  0.181659  2.012983  1.669293
# 股票4  0.146323 -1.334841 -0.821372 -0.304130  2.196566
# 股票5 -0.562976  1.563391 -0.321581 -1.648715  0.198683
# 股票6 -0.068277  0.531069 -1.778300  1.112068 -0.319578
# 股票7 -0.553139 -0.307676 -1.977479 -0.404189 -0.149432
# 股票8 -0.452568  1.678943  1.426117  1.657679  0.011011
# 股票9  0.718751 -0.455796  1.109148  0.537275 -0.529999

# %%
# 添加列索引
date=pd.date_range(start="20220330",periods=5,freq="B")

# %%
data=pd.DataFrame(stock_change,index=stock,columns=date)
data
# Out:
#      2022-03-30  2022-03-31  2022-04-01  2022-04-04  2022-04-05
# 股票0    0.602853   -1.315148   -0.090350   -1.567605   -0.579700
# 股票1    0.769553    0.510488    1.862448   -0.052457   -0.157931
# 股票2    2.130841    0.241595   -0.723202   -0.341976   -0.303318
# 股票3   -1.554739    0.044235    0.181659    2.012983    1.669293
# 股票4    0.146323   -1.334841   -0.821372   -0.304130    2.196566
# 股票5   -0.562976    1.563391   -0.321581   -1.648715    0.198683
# 股票6   -0.068277    0.531069   -1.778300    1.112068   -0.319578
# 股票7   -0.553139   -0.307676   -1.977479   -0.404189   -0.149432
# 股票8   -0.452568    1.678943    1.426117    1.657679    0.011011
# 股票9    0.718751   -0.455796    1.109148    0.537275   -0.529999

# %% [markdown]
# ### DataFrame属性

# %%
data.shape
# Out:
# (10, 5)

# %%
data.index
# Out:
# Index(['股票0', '股票1', '股票2', '股票3', '股票4', '股票5', '股票6', '股票7', '股票8', '股票9'], dtype='object')

# %%
data.columns
# Out:
# DatetimeIndex(['2022-03-30', '2022-03-31', '2022-04-01', '2022-04-04',
#                '2022-04-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
data.values
# Out:
# array([[ 0.60285313, -1.31514826, -0.09034986, -1.56760496, -0.57970034],
#        [ 0.76955317,  0.51048755,  1.86244757, -0.05245673, -0.15793113],
#        [ 2.13084099,  0.24159464, -0.72320166, -0.34197566, -0.30331801],
#        [-1.55473866,  0.04423487,  0.181659  ,  2.01298332,  1.66929339],
#        [ 0.14632285, -1.33484076, -0.82137247, -0.30413048,  2.19656638],
#        [-0.56297611,  1.56339101, -0.32158122, -1.64871465,  0.19868331],
#        [-0.06827659,  0.53106893, -1.77830019,  1.11206786, -0.31957809],
#        [-0.55313933, -0.3076756 , -1.97747908, -0.40418892, -0.14943198],
#        [-0.45256832,  1.67894313,  1.42611712,  1.65767857,  0.01101082],
#        [ 0.71875098, -0.45579611,  1.1091478 ,  0.53727524, -0.52999865]])

# %%
data.head() # 默认5行
# Out:
#      2022-03-30  2022-03-31  2022-04-01  2022-04-04  2022-04-05
# 股票0    0.602853   -1.315148   -0.090350   -1.567605   -0.579700
# 股票1    0.769553    0.510488    1.862448   -0.052457   -0.157931
# 股票2    2.130841    0.241595   -0.723202   -0.341976   -0.303318
# 股票3   -1.554739    0.044235    0.181659    2.012983    1.669293
# 股票4    0.146323   -1.334841   -0.821372   -0.304130    2.196566

# %%
data.tail(2)
# Out:
#      2022-03-30  2022-03-31  2022-04-01  2022-04-04  2022-04-05
# 股票8   -0.452568    1.678943    1.426117    1.657679    0.011011
# 股票9    0.718751   -0.455796    1.109148    0.537275   -0.529999

# %% [markdown]
# ### 修改行列索引值

# %%
# 不能单独修改某个索引，需要整体修改

# %%
stock=["股票-{}".format(i) for i in range(10)]

# %%
data.index=stock

# %%
data
# Out:
#       2022-03-30  2022-03-31  2022-04-01  2022-04-04  2022-04-05
# 股票-0    0.602853   -1.315148   -0.090350   -1.567605   -0.579700
# 股票-1    0.769553    0.510488    1.862448   -0.052457   -0.157931
# 股票-2    2.130841    0.241595   -0.723202   -0.341976   -0.303318
# 股票-3   -1.554739    0.044235    0.181659    2.012983    1.669293
# 股票-4    0.146323   -1.334841   -0.821372   -0.304130    2.196566
# 股票-5   -0.562976    1.563391   -0.321581   -1.648715    0.198683
# 股票-6   -0.068277    0.531069   -1.778300    1.112068   -0.319578
# 股票-7   -0.553139   -0.307676   -1.977479   -0.404189   -0.149432
# 股票-8   -0.452568    1.678943    1.426117    1.657679    0.011011
# 股票-9    0.718751   -0.455796    1.109148    0.537275   -0.529999

# %%
# 重设索引
data.reset_index()
# 默认drop属性为false，在原来的索引不删除
# Out:
#   index  2022-03-30 00:00:00  2022-03-31 00:00:00  2022-04-01 00:00:00  \
# 0  股票-0             0.602853            -1.315148            -0.090350
# 1  股票-1             0.769553             0.510488             1.862448
# 2  股票-2             2.130841             0.241595            -0.723202
# 3  股票-3            -1.554739             0.044235             0.181659
# 4  股票-4             0.146323            -1.334841            -0.821372
# 5  股票-5            -0.562976             1.563391            -0.321581
# 6  股票-6            -0.068277             0.531069            -1.778300
# 7  股票-7            -0.553139            -0.307676            -1.977479
# 8  股票-8            -0.452568             1.678943             1.426117
# 9  股票-9             0.718751            -0.455796             1.109148
#
#    2022-04-04 00:00:00  2022-04-05 00:00:00
# 0            -1.567605            -0.579700
# 1            -0.052457            -0.157931
# 2            -0.341976            -0.303318
# ...

# %%
# 需要设置drop属性为TRUE
data.reset_index(drop=True)
# Out:
#    2022-03-30  2022-03-31  2022-04-01  2022-04-04  2022-04-05
# 0    0.602853   -1.315148   -0.090350   -1.567605   -0.579700
# 1    0.769553    0.510488    1.862448   -0.052457   -0.157931
# 2    2.130841    0.241595   -0.723202   -0.341976   -0.303318
# 3   -1.554739    0.044235    0.181659    2.012983    1.669293
# 4    0.146323   -1.334841   -0.821372   -0.304130    2.196566
# 5   -0.562976    1.563391   -0.321581   -1.648715    0.198683
# 6   -0.068277    0.531069   -1.778300    1.112068   -0.319578
# 7   -0.553139   -0.307676   -1.977479   -0.404189   -0.149432
# 8   -0.452568    1.678943    1.426117    1.657679    0.011011
# 9    0.718751   -0.455796    1.109148    0.537275   -0.529999

# %%
# 设置新索引

df = pd.DataFrame({'month': [1, 4, 7, 10],
                    'year': [2012, 2014, 2013, 2014],
                    'sale':[55, 40, 84, 31]})

# %%
df
# Out:
#    month  sale  year
# 0      1    55  2012
# 1      4    40  2014
# 2      7    84  2013
# 3     10    31  2014

# %%
# 将月份设置为新索引 drop默认为True
df.set_index("month",drop=False)
# Out:
#        month  sale  year
# month
# 1          1    55  2012
# 4          4    40  2014
# 7          7    84  2013
# 10        10    31  2014

# %%
# 设置多个列表，需要使用列表
new_df=df.set_index(["year","month"])

# %%
new_df.index # MultiIndex
# Out:
# MultiIndex(levels=[[2012, 2013, 2014], [1, 4, 7, 10]],
#            labels=[[0, 2, 1, 2], [0, 1, 2, 3]],
#            names=['year', 'month'])

# %% [markdown]
# ### MultiIndex 与Panel

# %%
new_df.index.names
# Out:
# FrozenList(['year', 'month'])

# %%
new_df.index.levels
# Out:
# FrozenList([[2012, 2013, 2014], [1, 4, 7, 10]])

# %%
# Panel

# %%
p = pd.Panel(np.arange(24).reshape(4,3,2),
                 items=list('ABCD'),
                 major_axis=pd.date_range('20130101', periods=3),
                 minor_axis=['first', 'second'])

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 4 (items) x 3 (major_axis) x 2 (minor_axis)
# Items axis: A to D
# Major_axis axis: 2013-01-01 00:00:00 to 2013-01-03 00:00:00
# Minor_axis axis: first to second

# %%
p["D"]
# Out:
#             first  second
# 2013-01-01     18      19
# 2013-01-02     20      21
# 2013-01-03     22      23

# %%
p.major_xs("2013-01-01")
# Out:
#         A  B   C   D
# first   0  6  12  18
# second  1  7  13  19

# %%
# Series

# %%
data
# Out:
#       2022-03-30  2022-03-31  2022-04-01  2022-04-04  2022-04-05
# 股票-0    0.602853   -1.315148   -0.090350   -1.567605   -0.579700
# 股票-1    0.769553    0.510488    1.862448   -0.052457   -0.157931
# 股票-2    2.130841    0.241595   -0.723202   -0.341976   -0.303318
# 股票-3   -1.554739    0.044235    0.181659    2.012983    1.669293
# 股票-4    0.146323   -1.334841   -0.821372   -0.304130    2.196566
# 股票-5   -0.562976    1.563391   -0.321581   -1.648715    0.198683
# 股票-6   -0.068277    0.531069   -1.778300    1.112068   -0.319578
# 股票-7   -0.553139   -0.307676   -1.977479   -0.404189   -0.149432
# 股票-8   -0.452568    1.678943    1.426117    1.657679    0.011011
# 股票-9    0.718751   -0.455796    1.109148    0.537275   -0.529999

# %%
sr=data.iloc[1,:] # 带索引的一维数组

# %%
sr.index
# Out:
# DatetimeIndex(['2022-03-30', '2022-03-31', '2022-04-01', '2022-04-04',
#                '2022-04-05'],
#               dtype='datetime64[ns]', freq='B')

# %%
sr.values
# Out:
# array([ 0.76955317,  0.51048755,  1.86244757, -0.05245673, -0.15793113])

# %%
import numpy as np

# %%
pd.Series(np.arange(3,9,2),index=["a","b","c"])
# Out:
# a    3
# b    5
# c    7
# dtype: int64
